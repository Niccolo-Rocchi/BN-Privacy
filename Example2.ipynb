# %% [markdown]
# ## IDM Learning of a Credal Network

# %%
import random
import numpy as np
import math
from statsmodels.distributions.empirical_distribution import ECDF
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from scipy.stats import norm

import pyagrum as gum
import pyagrum.lib.notebook as gnb

# %%
# Set seeds
random.seed(42)
gum.initRandom(seed=42)

# %%
# Init BN
bn=gum.fastBN("A[2]->B[3]")

# Generate data from BN
gpop_ss = 1000
g = gum.BNDatabaseGenerator(bn)
g.drawSamples(gpop_ss)
g.setDiscretizedLabelModeRandom()
gpop = g.to_pandas()

assert(gpop.shape[0]==gpop_ss)

# %%
# Add counts of events to BN
for node in bn.names():
    var = bn.variable(node)
    parents = bn.parents(node)
    parent_names = [bn.variable(p).name() for p in parents]

    shape = [bn.variable(p).domainSize() for p in parents] + [var.domainSize()]
    counts_array = np.zeros(shape, dtype=float)  # float, non int!

    for _, row in gpop.iterrows():
        try:
            key = tuple([int(row[p]) for p in parent_names] + [int(row[node])])
            counts_array[key] += 1.0
        except KeyError:
            continue

    bn.cpt(node).fillWith(counts_array.flatten().tolist())

# %%
# Plot BN
gnb.flow.row(bn, bn.cpt("A"), bn.cpt("B"), captions=["CN", "CPT (A)", "CPT (B | A)"])
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="62pt" height="116pt" viewBox="0.00 0.00 62.00 116.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 112)">
# <title>G</title>
# <!-- A -->
# <g id="node1" class="node">
# <title>A</title>
# <g id="a_node1"><a xlink:title="(0) A">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="27" cy="-90" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-86.3" font-family="Times,serif" font-size="14.00" fill="white">A</text>
# </a>
# </g>
# </g>
# <!-- B -->
# <g id="node2" class="node">
# <title>B</title>
# <g id="a_node2"><a xlink:title="(1) B">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="27" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">B</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;B -->
# <g id="edge1" class="edge">
# <title>A-&gt;B</title>
# <g id="a_edge1"><a xlink:title="0 → 1">
# <path fill="none" stroke="#4a4a4a" d="M27,-71.7C27,-63.98 27,-54.71 27,-46.11"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="30.5,-46.1 27,-36.1 23.5,-46.1 30.5,-46.1"/>
# </a>
# </g>
# </g>
# </g>
# </svg><br><center><small><em>CN</em></small></center></div><div class="floating-box"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>A</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='text-align:right;padding: 3px;'>98.0000</td><td style='text-align:right;padding: 3px;'>902.0000</td></tr>
# </table><br><center><small><em>CPT (A)</em></small></center></div><div class="floating-box"><table style="border:1px solid black;border-collapse: collapse;">
# <tr><th colspan='1'></th>
#       <th colspan='3' style='border:1px solid black;color:black;background-color:#808080;'><center>B</center>
#       </th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>A</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>2</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='text-align:right;padding: 3px;'>37.0000</td><td style='text-align:right;padding: 3px;'>17.0000</td><td style='text-align:right;padding: 3px;'>44.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='text-align:right;padding: 3px;'>488.0000</td><td style='text-align:right;padding: 3px;'>349.0000</td><td style='text-align:right;padding: 3px;'>65.0000</td></tr>
# </table><br><center><small><em>CPT (B | A)</em></small></center></div>

# %%
# Quick check
c = gpop[gpop["A"]=="0"]
print(f"Counts of A=0: {len(c)}")
assert(len(c) == bn.cpt("A")[0])

c = c[c["B"] == '2']
print(f"Counts of B=2 | A=0: {len(c)}")
assert(len(c) == bn.cpt("B")[0,2])
# Out:
# Counts of A=0: 98
# Counts of B=2 | A=0: 44

# %%
# Convert BN to CN
cn = gum.CredalNet(bn)

# IDM Learning ('s' must be integer)
cn.idmLearning(s=2)

# %%
# Plot CN
ie_mc=gum.CNMonteCarloSampling(cn)
gnb.sideBySide(cn, gnb.getInference(cn,engine=ie_mc))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="62pt" height="116pt" viewBox="0.00 0.00 62.00 116.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 112)">
# <title>G</title>
# <!-- A -->
# <g id="node1" class="node">
# <title>A</title>
# <g id="a_node1"><a xlink:title="(0) A">
# <polygon fill="#404040" stroke="#4a4a4a" points="54,-85.99 48.65,-101.22 27,-108 5.35,-101.22 0,-85.99 14.98,-73.78 39.02,-73.78 54,-85.99"/>
# <text text-anchor="middle" x="27" y="-86.3" font-family="Times,serif" font-size="14.00" fill="white">A</text>
# </a>
# </g>
# </g>
# <!-- B -->
# <g id="node2" class="node">
# <title>B</title>
# <g id="a_node2"><a xlink:title="(1) B">
# <polygon fill="#404040" stroke="#4a4a4a" points="54,-13.99 48.65,-29.22 27,-36 5.35,-29.22 0,-13.99 14.98,-1.78 39.02,-1.78 54,-13.99"/>
# <text text-anchor="middle" x="27" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">B</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;B -->
# <g id="edge1" class="edge">
# <title>A-&gt;B</title>
# <g id="a_edge1"><a xlink:title="0 → 1">
# <path fill="none" stroke="#4a4a4a" d="M27,-73.46C27,-65.59 27,-55.79 27,-46.68"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="30.5,-46.46 27,-36.46 23.5,-46.46 30.5,-46.46"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;vertical-align:middle;"><div align="center" style="vertical-align:middle;"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="181pt" height="161pt" viewBox="0.00 0.00 181.00 161.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 157)">
# <title>structs</title>
# <text text-anchor="middle" x="86.5" y="-7.8" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">Inference in  12.55ms</text>
# <!-- A -->
# <g id="node1" class="node">
# <title>A</title>
# <polygon fill="#e0e0e0" stroke="#000000" points="137,-153 36,-153 36,-111 137,-111 137,-153"/>
# <svg viewBox="0 0 132.1625 53.538125" width="101px" height="42px" preserveAspectRatio="xMinYMin meet" x="36" y="-153"> <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2025-04-15T11:40:08.223563</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.10.1, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 53.538125  L 132.1625 53.538125  L 132.1625 0  L 0 0  z " style="fill: #e0e0e0"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 46.438125  L 128.5625 46.438125  L 128.5625 18.718125  L 16.9625 18.718125  z " style="fill: #ffffff"/>
#    </g>
#    <g id="patch_3">
#     <path d="M 16.9625 46.438125  L 117.64753 46.438125  L 117.64753 34.118125  L 16.9625 34.118125  z " clip-path="url(#pc8fe824bac)" style="fill: #bbffaa"/>
#    </g>
#    <g id="patch_4">
#     <path d="M 16.9625 31.038125  L 28.100225 31.038125  L 28.100225 18.718125  L 16.9625 18.718125  z " clip-path="url(#pc8fe824bac)" style="fill: #bbffaa"/>
#    </g>
#    <g id="patch_5">
#     <path d="M 16.9625 46.438125  L 117.424775 46.438125  L 117.424775 34.118125  L 16.9625 34.118125  z " clip-path="url(#pc8fe824bac)" style="fill: #8fbc8f"/>
#    </g>
#    <g id="patch_6">
#     <path d="M 16.9625 31.038125  L 27.87747 31.038125  L 27.87747 18.718125  L 16.9625 18.718125  z " clip-path="url(#pc8fe824bac)" style="fill: #8fbc8f"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path d="M 16.9625 46.438125  L 16.9625 18.718125  " clip-path="url(#pc8fe824bac)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path id="m17e6bf8adb" d="M 0 0  L 0 3.5  " style="stroke: #000000; stroke-width: 0.8"/>
#       </defs>
#       <g>
#        <use xlink:href="#m17e6bf8adb" x="16.9625" y="46.438125" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path d="M 72.7625 46.438125  L 72.7625 18.718125  " clip-path="url(#pc8fe824bac)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use xlink:href="#m17e6bf8adb" x="72.7625" y="46.438125" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path d="M 128.5625 46.438125  L 128.5625 18.718125  " clip-path="url(#pc8fe824bac)" style="fill: none; stroke: #b0b0b0; stroke-width: 0.8; stroke-linecap: square"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use xlink:href="#m17e6bf8adb" x="128.5625" y="46.438125" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="matplotlib.axis_2">
#     <g id="ytick_1">
#      <g id="line2d_7">
#       <defs>
#        <path id="mfd5940e36d" d="M 0 0  L -3.5 0  " style="stroke: #000000; stroke-width: 0.8"/>
#       </defs>
#       <g>
#        <use xlink:href="#mfd5940e36d" x="16.9625" y="40.278125" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 1 -->
#       <g transform="translate(3.6 44.077344) scale(0.1 -0.1)">
#        <defs>
#         <path id="DejaVuSans-31" d="M 794 531  L 1825 531  L 1825 4091  L 703 3866  L 703 4441  L 1819 4666  L 2450 4666  L 2450 531  L 3481 531  L 3481 0  L 794 0  L 794 531  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-31"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_2">
#      <g id="line2d_8">
#       <g>
#        <use xlink:href="#mfd5940e36d" x="16.9625" y="24.878125" style="stroke: #000000; stroke-width: 0.8"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 0 -->
#       <g transform="translate(3.6 28.677344) scale(0.1 -0.1)">
#        <defs>
#         <path id="DejaVuSans-30" d="M 2034 4250  Q 1547 4250 1301 3770  Q 1056 3291 1056 2328  Q 1056 1369 1301 889  Q 1547 409 2034 409  Q 2525 409 2770 889  Q 3016 1369 3016 2328  Q 3016 3291 2770 3770  Q 2525 4250 2034 4250  z M 2034 4750  Q 2819 4750 3233 4129  Q 3647 3509 3647 2328  Q 3647 1150 3233 529  Q 2819 -91 2034 -91  Q 1250 -91 836 529  Q 422 1150 422 2328  Q 422 3509 836 4129  Q 1250 4750 2034 4750  z " transform="scale(0.015625)"/>
#        </defs>
#        <use xlink:href="#DejaVuSans-30"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="patch_7">
#     <path d="M 16.9625 46.438125  L 16.9625 18.718125  " style="fill: none; stroke: #000000; stroke-width: 0.8; stroke-linejoin: miter; stroke-linecap: square"/>
#    </g>
#    <g id="patch_8">
#     <path d="M 128.5625 46.438125  L 128.5625 18.718125  " style="fill: none; stroke: #000000; stroke-width: 0.8; stroke-linejoin: miter; stroke-linecap: square"/>
#    </g>
#    <g id="patch_9">
#     <path d="M 16.9625 46.438125  L 128.5625 46.438125  " style="fill: none; stroke: #000000; stroke-width: 0.8; stroke-linejoin: miter; stroke-linecap: square"/>
#    </g>
#    <g id="patch_10">
#     <path d="M 16.9625 18.718125  L 128.5625 18.718125  " style="fill: none; stroke: #000000; stroke-width: 0.8; stroke-linejoin: miter; stroke-linecap: square"/>
#    </g>
#    <g id="text_3">
#     <!-- 90.22% -->
#     <g transform="translate(90.432812 44.358438) scale(0.1 -0.1)">
#      <defs>
#       <path id="DejaVuSans-39" d="M 703 97  L 703 672  Q 941 559 1184 500  Q 1428 441 1663 441  Q 2288 441 2617 861  Q 2947 1281 2994 2138  Q 2813 1869 2534 1725  Q 2256 1581 1919 1581  Q 1219 1581 811 2004  Q 403 2
