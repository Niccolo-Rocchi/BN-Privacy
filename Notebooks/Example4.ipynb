# %% [markdown]
# ## Evaluating `pyagrum` inferences on CN

# %%
import sys
import os
sys.path.append(os.path.abspath("../src"))
from utils import *
from run import *
import random
import numpy as np
import pandas as pd
import math
import pyagrum as gum
import pyagrum.lib.notebook as gnb

# %%
# Set seeds
random.seed(42)
gum.initRandom(seed=42)

# %%
bn=gum.fastBN("X1[2]<-T[2]->X2[2]; T->X3[2]; T->X4[2]; T->X5[2]; T->X6[2]; T->X7[2]; T->X8[2]; T->X9[2]; T->X0[2];")
gnb.flow.row(bn, bn.cpt("T"), bn.cpt("X1"))
# Out:
#       <style>
#       .floating-box {
#       display: inline-block;
#       margin: 7px;
#       padding : 3px;
#       border: 0px solid transparent;
#       valign:middle;
#       background-color: transparent;
#       }
#       </style>
#       <div class="floating-box"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="360pt" height="59pt" viewBox="0.00 0.00 360.00 58.82">
# <g id="graph0" class="graph" transform="scale(0.51 0.51) rotate(0) translate(4 112)">
# <title>G</title>
# <!-- X9 -->
# <g id="node1" class="node">
# <title>X9</title>
# <g id="a_node1"><a xlink:title="(9) X9">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="27" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">X9</text>
# </a>
# </g>
# </g>
# <!-- X0 -->
# <g id="node2" class="node">
# <title>X0</title>
# <g id="a_node2"><a xlink:title="(10) X0">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="99" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="99" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">X0</text>
# </a>
# </g>
# </g>
# <!-- X5 -->
# <g id="node3" class="node">
# <title>X5</title>
# <g id="a_node3"><a xlink:title="(5) X5">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="171" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="171" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">X5</text>
# </a>
# </g>
# </g>
# <!-- X3 -->
# <g id="node4" class="node">
# <title>X3</title>
# <g id="a_node4"><a xlink:title="(3) X3">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="243" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="243" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">X3</text>
# </a>
# </g>
# </g>
# <!-- X7 -->
# <g id="node5" class="node">
# <title>X7</title>
# <g id="a_node5"><a xlink:title="(7) X7">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="315" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="315" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">X7</text>
# </a>
# </g>
# </g>
# <!-- X2 -->
# <g id="node6" class="node">
# <title>X2</title>
# <g id="a_node6"><a xlink:title="(2) X2">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="387" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="387" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">X2</text>
# </a>
# </g>
# </g>
# <!-- X4 -->
# <g id="node7" class="node">
# <title>X4</title>
# <g id="a_node7"><a xlink:title="(4) X4">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="459" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="459" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">X4</text>
# </a>
# </g>
# </g>
# <!-- X8 -->
# <g id="node8" class="node">
# <title>X8</title>
# <g id="a_node8"><a xlink:title="(8) X8">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="531" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="531" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">X8</text>
# </a>
# </g>
# </g>
# <!-- X1 -->
# <g id="node9" class="node">
# <title>X1</title>
# <g id="a_node9"><a xlink:title="(0) X1">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="603" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="603" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">X1</text>
# </a>
# </g>
# </g>
# <!-- X6 -->
# <g id="node10" class="node">
# <title>X6</title>
# <g id="a_node10"><a xlink:title="(6) X6">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="675" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="675" y="-14.3" font-family="Times,serif" font-size="14.00" fill="white">X6</text>
# </a>
# </g>
# </g>
# <!-- T -->
# <g id="node11" class="node">
# <title>T</title>
# <g id="a_node11"><a xlink:title="(1) T">
# <ellipse fill="#404040" stroke="#4a4a4a" cx="351" cy="-90" rx="27" ry="18"/>
# <text text-anchor="middle" x="351" y="-86.3" font-family="Times,serif" font-size="14.00" fill="white">T</text>
# </a>
# </g>
# </g>
# <!-- T&#45;&gt;X9 -->
# <g id="edge10" class="edge">
# <title>T-&gt;X9</title>
# <g id="a_edge10"><a xlink:title="1 → 9">
# <path fill="none" stroke="#4a4a4a" d="M324.23,-86.42C272.66,-80.93 156.4,-66.08 63,-36 61.08,-35.38 59.12,-34.68 57.17,-33.93"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="58.14,-30.54 47.57,-29.83 55.39,-36.97 58.14,-30.54"/>
# </a>
# </g>
# </g>
# <!-- T&#45;&gt;X0 -->
# <g id="edge6" class="edge">
# <title>T-&gt;X0</title>
# <g id="a_edge6"><a xlink:title="1 → 10">
# <path fill="none" stroke="#4a4a4a" d="M325.24,-84.42C284.25,-76.74 201.96,-59.75 135,-36 133.09,-35.32 131.15,-34.58 129.21,-33.79"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="130.21,-30.41 119.64,-29.61 127.4,-36.82 130.21,-30.41"/>
# </a>
# </g>
# </g>
# <!-- T&#45;&gt;X5 -->
# <g id="edge2" class="edge">
# <title>T-&gt;X5</title>
# <g id="a_edge2"><a xlink:title="1 → 5">
# <path fill="none" stroke="#4a4a4a" d="M327.31,-81C298.56,-71.13 248.77,-53.51 207,-36 205.18,-35.24 203.32,-34.44 201.46,-33.61"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="202.73,-30.35 192.18,-29.38 199.83,-36.71 202.73,-30.35"/>
# </a>
# </g>
# </g>
# <!-- T&#45;&gt;X3 -->
# <g id="edge9" class="edge">
# <title>T-&gt;X3</title>
# <g id="a_edge9"><a xlink:title="1 → 3">
# <path fill="none" stroke="#4a4a4a" d="M332.19,-76.81C315,-65.67 289.38,-49.06 270.01,-36.5"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="271.89,-33.56 261.6,-31.05 268.08,-39.43 271.89,-33.56"/>
# </a>
# </g>
# </g>
# <!-- T&#45;&gt;X7 -->
# <g id="edge5" class="edge">
# <title>T-&gt;X7</title>
# <g id="a_edge5"><a xlink:title="1 → 7">
# <path fill="none" stroke="#4a4a4a" d="M342.65,-72.76C338.29,-64.28 332.85,-53.71 327.96,-44.2"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="330.99,-42.44 323.3,-35.15 324.77,-45.64 330.99,-42.44"/>
# </a>
# </g>
# </g>
# <!-- T&#45;&gt;X2 -->
# <g id="edge1" class="edge">
# <title>T-&gt;X2</title>
# <g id="a_edge1"><a xlink:title="1 → 2">
# <path fill="none" stroke="#4a4a4a" d="M359.35,-72.76C363.71,-64.28 369.15,-53.71 374.04,-44.2"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="377.23,-45.64 378.7,-35.15 371.01,-42.44 377.23,-45.64"/>
# </a>
# </g>
# </g>
# <!-- T&#45;&gt;X4 -->
# <g id="edge4" class="edge">
# <title>T-&gt;X4</title>
# <g id="a_edge4"><a xlink:title="1 → 4">
# <path fill="none" stroke="#4a4a4a" d="M369.81,-76.81C387,-65.67 412.62,-49.06 431.99,-36.5"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="433.92,-39.43 440.4,-31.05 430.11,-33.56 433.92,-39.43"/>
# </a>
# </g>
# </g>
# <!-- T&#45;&gt;X8 -->
# <g id="edge3" class="edge">
# <title>T-&gt;X8</title>
# <g id="a_edge3"><a xlink:title="1 → 8">
# <path fill="none" stroke="#4a4a4a" d="M374.69,-81C403.44,-71.13 453.23,-53.51 495,-36 496.82,-35.24 498.68,-34.44 500.54,-33.61"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="502.17,-36.71 509.82,-29.38 499.27,-30.35 502.17,-36.71"/>
# </a>
# </g>
# </g>
# <!-- T&#45;&gt;X1 -->
# <g id="edge7" class="edge">
# <title>T-&gt;X1</title>
# <g id="a_edge7"><a xlink:title="1 → 0">
# <path fill="none" stroke="#4a4a4a" d="M376.76,-84.42C417.75,-76.74 500.04,-59.75 567,-36 568.91,-35.32 570.85,-34.58 572.79,-33.79"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="574.6,-36.82 582.36,-29.61 571.79,-30.41 574.6,-36.82"/>
# </a>
# </g>
# </g>
# <!-- T&#45;&gt;X6 -->
# <g id="edge8" class="edge">
# <title>T-&gt;X6</title>
# <g id="a_edge8"><a xlink:title="1 → 6">
# <path fill="none" stroke="#4a4a4a" d="M377.77,-86.42C429.34,-80.93 545.6,-66.08 639,-36 640.92,-35.38 642.88,-34.68 644.83,-33.93"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="646.61,-36.97 654.43,-29.83 643.86,-30.54 646.61,-36.97"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div><div class="floating-box"><table style="border:1px solid black;border-collapse: collapse;">
# <tr style='border:1px solid black;color:black;background-color:#808080'>
#       <th colspan='2'><center>T</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'>
#       <center>1</center></th></tr>
# <tr><td style='color:black;background-color:#fa8364;text-align:right;padding: 3px;'>0.0332</td><td style='color:black;backgro

# %%
# Generate data from BN
gpop_ss = 5000
ratio = 6
pool_ss = gpop_ss // ratio
rpop_ss = gpop_ss - pool_ss
g = gum.BNDatabaseGenerator(bn)
g.drawSamples(gpop_ss)
g.setDiscretizedLabelModeRandom()
gpop = g.to_pandas()
pool_idx = np.random.choice(gpop_ss, replace=False, size=pool_ss)
pool = gpop.iloc[pool_idx]
rpop = gpop.iloc[~ gpop.index.isin(pool_idx)]

# %%
# Estimate CN by local IDM from BN(theta_hat)
ess = 5
bn_copy = gum.BayesNet(bn)
add_counts_to_bn(bn_copy, pool)
cn = gum.CredalNet(bn_copy)
cn.idmLearning(ess)

# %%
# Evidence list
evid_vec = [random_product(*((0,1) for _ in range(bn.size() - 1))) for _ in range(100)]

# %%
bn_ie = gum.LazyPropagation(bn)
e = evid_vec[10]
cov = sorted([i for i in bn.names()])
cov.remove("T")
evid = {k:v for k,v in zip(cov, e)}
evid
# Out:
# {'X0': 1,
#  'X1': 1,
#  'X2': 1,
#  'X3': 0,
#  'X4': 0,
#  'X5': 1,
#  'X6': 1,
#  'X7': 0,
#  'X8': 1,
#  'X9': 1}

# %%
# BN inferences
bn_mpes, bn_probs = run_inference_bn(bn, evid_vec)

# Pyagrum inferences
cn_mpes, cn_probs = run_inference_cn_pyagrum(cn, evid_vec)
cn_probs = np.array(cn_probs)

print(f"CN certainty (pyagrum): {sum(cn_probs > 0.5) * 100/ len(cn_probs):.1f} %")

# No-pyagrum inferences
my_cn_mpes, my_cn_log_probs = run_inference_cn(cn, evid_vec)
my_cn_probs = np.array([math.exp(p) for p in my_cn_log_probs])

print(f"CN certainty (no pyagrum): {sum(my_cn_probs > 0.5) * 100/ len(my_cn_probs):.1f} %")
# Out:
# CN certainty (pyagrum): 98.0 %
# CN certainty (no pyagrum): 79.0 %

# %%
results = pd.DataFrame(
    {"bn_mpes": bn_mpes,
     "bn_probs": bn_probs,
     "py_mpes": cn_mpes, 
     "py_probs": cn_probs, 
     "my_mpes": my_cn_mpes,
     "my_probs": my_cn_probs}
)

results
# Out:
#     bn_mpes  bn_probs  py_mpes  py_probs  my_mpes  my_probs
# 0         1  0.999800        1  0.994443        1  0.994444
# 1         1  0.959044        1  0.624536        1  0.624538
# 2         1  0.949950        1  0.782433        1  0.782434
# 3         1  0.909082        1  0.783721        1  0.783722
# 4         1  0.987497        1  0.805699        1  0.805700
# ..      ...       ...      ...       ...      ...       ...
# 95        1  0.984942        1  0.933517        1  0.933518
# 96        1  0.995730        1  0.968381        1  0.968382
# 97        1  0.873905        0  0.665917        1  0.300374
# 98        1  0.998249        1  0.974472        1  0.974472
# 99        1  0.992020        1  0.948644        1  0.948644
#
# [100 rows x 6 columns]

# %%
print("CN (pyagrum) accuracy: ", sum(results["py_mpes"] == results["bn_mpes"]) / len(results))
print("CN (no pyagrum) accuracy: ", sum(results["my_mpes"] == results["bn_mpes"]) / len(results))
# Out:
# CN (pyagrum) accuracy:  0.84
# CN (no pyagrum) accuracy:  1.0
